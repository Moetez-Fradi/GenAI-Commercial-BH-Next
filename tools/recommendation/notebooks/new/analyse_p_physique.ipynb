# %% [markdown]
# importing dependencies

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_excel('../../data/Donn_es_Assurance_S2.1.xlsx',sheet_name='personne_physique')

# %% [markdown]
# Initial exploration

# %%
print('Dataset shape:',df.shape)
print("\nColumn Names:", df.columns.tolist())
print("\nData Types:\n", df.dtypes)
print("\nFirst 5 rows:\n", df.head())
print("\nBasic Info:")
df.info()
# Out:
# Dataset shape: (43314, 12)
#
# Column Names: ['REF_PERSONNE', 'NOM_PRENOM', 'DATE_NAISSANCE', 'LIEU_NAISSANCE', 'CODE_SEXE', 'SITUATION_FAMILIALE', 'NUM_PIECE_IDENTITE', 'LIB_SECTEUR_ACTIVITE', 'LIB_PROFESSION', 'VILLE', 'LIB_GOUVERNORAT', 'VILLE_GOUVERNORAT']
#
# Data Types:
#  REF_PERSONNE             int64
# NOM_PRENOM              object
# DATE_NAISSANCE          object
# LIEU_NAISSANCE          object
# CODE_SEXE               object
# SITUATION_FAMILIALE     object
# NUM_PIECE_IDENTITE       int64
# LIB_SECTEUR_ACTIVITE    object
# LIB_PROFESSION          object
# VILLE                   object
# LIB_GOUVERNORAT         object
# VILLE_GOUVERNORAT       object
# dtype: object
#
# First 5 rows:
#     REF_PERSONNE      NOM_PRENOM           DATE_NAISSANCE LIEU_NAISSANCE  \
# 0           715  Personne_00001  1964-09-28 00:00:00.000            NaN
# 1          1381  Personne_00002  1962-02-27 00:00:00.000          TUNIS
# 2          1947  Personne_00003  1970-04-17 00:00:00.000          TUNIS
# 3          2832  Personne_00004  1974-03-31 00:00:00.000          TUNIS
# 4          3060  Personne_00005  1968-05-06 00:00:00.000          TUNIS
#
#   CODE_SEXE SITUATION_FAMILIALE  NUM_PIECE_IDENTITE  \
# 0         M               Marie            10000001
# 1         M               Marie            10000002
# 2         M               Marie            10000003
# 3         F               Marie            10000004
# 4         M               Marie            10000005
#
#                                 LIB_SECTEUR_ACTIVITE  \
# 0  CADRES ET PROFESSIONS INTELLECTUELLES SUPÉRIEURES
# 1                                SERVICES PERSONNELS
# 2                                         COMMERCIAL
# 3                                              AUCUN
# 4                                              AUCUN
#
#                    LIB_PROFESSION            VILLE LIB_GOUVERNORAT  \
# 0  MÉDECINS LIBÉRAUX GÉNÉRALISTES              NaN             NaN
# 1                       CHAUFFEUR  NOUVELLE MEDINA             NaN
# 2                      COMMERCIAL        JBAL RSAS       BEN AROUS
# 3                     NON DEFINIE              NaN             NaN
# 4                     NON DEFINIE       El Hrairia           TUNIS
#
#        VILLE_GOUVERNORAT
# 0                     -
# 1     NOUVELLE MEDINA -
# 2  JBAL RSAS - BEN AROUS
# 3                     -
# 4     El Hrairia - TUNIS
#
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43314 entries, 0 to 43313
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   REF_PERSONNE          43314 non-null  int64
#  1   NOM_PRENOM            43314 non-null  object
#  2   DATE_NAISSANCE        42377 non-null  object
#  3   LIEU_NAISSANCE        37661 non-null  object
#  4   CODE_SEXE             43314 non-null  object
#  5   SITUATION_FAMILIALE   43314 non-null  object
#  6   NUM_PIECE_IDENTITE    43314 non-null  int64
#  7   LIB_SECTEUR_ACTIVITE  43313 non-null  object
#  8   LIB_PROFESSION        40512 non-null  object
#  9   VILLE                 28617 non-null  object
#  10  LIB_GOUVERNORAT       15391 non-null  object
#  11  VILLE_GOUVERNORAT     43314 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 4.0+ MB

# %% [markdown]
# Data quality assessment

# %%
def assess_data_quality(df):
    """Comprehensive data quality assessment"""
    
    # Missing values analysis
    missing_stats = pd.DataFrame({
        'Missing_Count': df.isnull().sum(),
        'Missing_Percentage': (df.isnull().sum() / len(df)) * 100,
        'Unique_Values': df.nunique()
    })
    
    print("Missing Values Analysis:")
    print(missing_stats)
    
    # Data type validation
    print("\nData Type Validation:")
    for col in df.columns:
        print(f"{col}: {df[col].dtype}")
    
    return missing_stats


quality_report = assess_data_quality(df)
# Out:
# Missing Values Analysis:
#                       Missing_Count  Missing_Percentage  Unique_Values
# REF_PERSONNE                      0            0.000000          43314
# NOM_PRENOM                        0            0.000000          43314
# DATE_NAISSANCE                  937            2.163273          18384
# LIEU_NAISSANCE                 5653           13.051207           5463
# CODE_SEXE                         0            0.000000              3
# SITUATION_FAMILIALE               0            0.000000              5
# NUM_PIECE_IDENTITE                0            0.000000          43314
# LIB_SECTEUR_ACTIVITE              1            0.002309             31
# LIB_PROFESSION                 2802            6.469040            690
# VILLE                         14697           33.931292           3362
# LIB_GOUVERNORAT               27923           64.466454             24
# VILLE_GOUVERNORAT                 0            0.000000           4054
#
# Data Type Validation:
# REF_PERSONNE: int64
# NOM_PRENOM: object
# DATE_NAISSANCE: object
# LIEU_NAISSANCE: object
# CODE_SEXE: object
# SITUATION_FAMILIALE: object
# NUM_PIECE_IDENTITE: int64
# LIB_SECTEUR_ACTIVITE: object
# LIB_PROFESSION: object
# VILLE: object
# LIB_GOUVERNORAT: object
# VILLE_GOUVERNORAT: object

# %% [markdown]
# Column-specific Cleaning

# %% [markdown]
# REF_PERSONNE Column

# %%
# checking for duplicates and validity
print('REF_PERSONNE unique values:',df['REF_PERSONNE'].nunique())
print('REF_PERSONNE duplicates:',df['REF_PERSONNE'].duplicated().sum())
# Out:
# REF_PERSONNE unique values: 43314
# REF_PERSONNE duplicates: 0

# %% [markdown]
# Nom_Prenom column

# %%
# Check name patterns and anomalies
print("Name column analysis:")
print("Unique names:", df['NOM_PRENOM'].nunique())
print("Sample names:", df['NOM_PRENOM'].head(10).tolist())

# Check for special characters or anomalies
x = df['NOM_PRENOM'].str.len()
print("Name length stats:",x.describe())
# Out:
# Name column analysis:
# Unique names: 43314
# Sample names: ['Personne_00001', 'Personne_00002', 'Personne_00003', 'Personne_00004', 'Personne_00005', 'Personne_00006', 'Personne_00007', 'Personne_00008', 'Personne_00009', 'Personne_00010']
# Name length stats: count    43314.0
# mean        14.0
# std          0.0
# min         14.0
# 25%         14.0
# 50%         14.0
# 75%         14.0
# max         14.0
# Name: NOM_PRENOM, dtype: float64

# %%
df.columns
# Out:
# Index(['REF_PERSONNE', 'NOM_PRENOM', 'DATE_NAISSANCE', 'LIEU_NAISSANCE',
#        'CODE_SEXE', 'SITUATION_FAMILIALE', 'NUM_PIECE_IDENTITE',
#        'LIB_SECTEUR_ACTIVITE', 'LIB_PROFESSION', 'VILLE', 'LIB_GOUVERNORAT',
#        'VILLE_GOUVERNORAT'],
#       dtype='object')

# %% [markdown]
# Date_Naissance Column

# %%
temp = df.copy()

# %%
def clean_age_data(df, date_col='DATE_NAISSANCE', min_age=18, max_age=100):

    temp = df.copy()
    
    # Convert to datetime and handle invalid dates
    temp[date_col] = pd.to_datetime(temp[date_col], errors='coerce')
    
    # Calculate age
    current_date = pd.Timestamp.now()
    temp['AGE'] = (current_date - temp[date_col]).dt.days // 365
    
    # Identify records with unrealistic ages
    mask_invalid_dates = temp[date_col].isnull()
    mask_too_young = temp['AGE'] < min_age
    mask_too_old = temp['AGE'] > max_age
    mask_future_dates = temp[date_col] > current_date
    mask_negative_age = temp['AGE'] < 0
    
    # Combine all invalid age conditions
    invalid_age_mask = (mask_invalid_dates | mask_too_young | mask_too_old | 
                       mask_future_dates | mask_negative_age)
    
    # Remove rows with unrealistic ages
    original_count = len(temp)
    temp = temp[~invalid_age_mask].copy()
    removed_count = original_count - len(temp)
    
    return temp, removed_count

# %%
df,removed_count = clean_age_data(df)

# %%
df.shape
# Out:
# (42065, 13)

# %% [markdown]
# LIEU_NAISSANCE Column

# %%
# Analyze birthplace data
print("Unique birthplaces:", df['LIEU_NAISSANCE'].nunique())
print("Missing birthplaces:", df['LIEU_NAISSANCE'].isnull().sum())

# Check for standardization issues
birthplace_counts = df['LIEU_NAISSANCE'].value_counts()
print("Top 10 birthplaces:\n", birthplace_counts.head(10))
# Out:
# Unique birthplaces: 5451
# Missing birthplaces: 4735
# Top 10 birthplaces:
#  LIEU_NAISSANCE
# TUNIS       7067
# GABES       2239
# SFAX        1612
# BIZERTE     1329
# SOUSSE      1191
# BEJA        1130
# KAIROUAN     632
# MONASTIR     565
# JENDOUBA     502
# NABEUL       373
# Name: count, dtype: int64

# %%
# Correct way: Direct assignment
df['LIEU_NAISSANCE'] = df['LIEU_NAISSANCE'].fillna('TUNIS')

# Verify the change
print("Missing birthplaces after fill:", df['LIEU_NAISSANCE'].isnull().sum())
print("New value count for 'TUNIS':", (df['LIEU_NAISSANCE'] == 'TUNIS').sum())
# Out:
# Missing birthplaces after fill: 0
# New value count for 'TUNIS': 11802

# %% [markdown]
# Checking for empty string values in birthplace

# %%
# Count the number of empty strings
empty_count = (df['LIEU_NAISSANCE'] == '').sum()
print(f"Number of empty strings: {empty_count}")

# You can also see the actual rows with empty strings
empty_birthplaces = df[df['LIEU_NAISSANCE'] == '']
print(f"Rows with empty birthplace:\n{empty_birthplaces}")
# Out:
# Number of empty strings: 0
# Rows with empty birthplace:
# Empty DataFrame
# Columns: [REF_PERSONNE, NOM_PRENOM, DATE_NAISSANCE, LIEU_NAISSANCE, CODE_SEXE, SITUATION_FAMILIALE, NUM_PIECE_IDENTITE, LIB_SECTEUR_ACTIVITE, LIB_PROFESSION, VILLE, LIB_GOUVERNORAT, VILLE_GOUVERNORAT, AGE]
# Index: []

# %% [markdown]
# CODE_SEXE Column

# %%
# Validate gender codes
print("Gender code distribution:")
print(df['CODE_SEXE'].value_counts())

# Check for invalid codes
valid_genders = ['M', 'F']
invalid_genders = df[~df['CODE_SEXE'].isin(valid_genders)]
print(f"Invalid gender codes: {len(invalid_genders)}")
# Out:
# Gender code distribution:
# CODE_SEXE
# M    29294
# F    12081
#        690
# Name: count, dtype: int64
# Invalid gender codes: 690

# %% [markdown]
# Handling empty string values in CODE_SEXE

# %%
# Replace empty strings with 'Unknown'
df['CODE_SEXE'] = df['CODE_SEXE'].replace('', 'Unknown')

# Verify the change
print("Gender code distribution after cleaning:")
print(df['CODE_SEXE'].value_counts())

# Check for invalid codes again (now only truly invalid entries, if any)
valid_genders = ['M', 'F', 'Unknown'] # Add 'Unknown' to the valid list for checking
invalid_genders = df[~df['CODE_SEXE'].isin(valid_genders)]
print(f"Invalid gender codes: {len(invalid_genders)}")
# Out:
# Gender code distribution after cleaning:
# CODE_SEXE
# M    29294
# F    12081
#        690
# Name: count, dtype: int64
# Invalid gender codes: 690

# %% [markdown]
# SITUATION_FAMILIALE COLUMN

# %%
# Analyze marital status
print("Marital status distribution:")
print(df['SITUATION_FAMILIALE'].value_counts())
# Out:
# Marital status distribution:
# SITUATION_FAMILIALE
# Marie          30193
# Celibataire     9509
#                 1518
# Veuf(ve)         508
# Divorce          337
# Name: count, dtype: int64

# %% [markdown]
# Handling empty string values in SITUATION_FAMILIALE

# %%
# 1. Check initial state and confirm whitespace entries
print("Initial Marital Status Distribution:")
print(df['SITUATION_FAMILIALE'].value_counts())
whitespace_count = (df['SITUATION_FAMILIALE'].str.strip() == '').sum()
print(f"Initial whitespace-only entries: {whitespace_count}\n")

# 2. Replace whitespace-only strings with 'Unknown'
mask = df['SITUATION_FAMILIALE'].str.strip() == ''
df.loc[mask, 'SITUATION_FAMILIALE'] = 'Unknown'

# 3. Verify the cleanup was successful
print("Final Marital Status Distribution:")
final_counts = df['SITUATION_FAMILIALE'].value_counts()
print(final_counts)
print(f"\nTotal 'Unknown' entries: {final_counts.get('Unknown', 0)}")

# 4. Final validation check
valid_statuses = ['Marie', 'Celibataire', 'Veuf(ve)', 'Divorce', 'Unknown']
is_valid = df['SITUATION_FAMILIALE'].isin(valid_statuses)
print(f"Rows with valid marital status: {is_valid.sum()}/{len(df)}")
print(f"Rows with invalid marital status: {(~is_valid).sum()}")
# Out:
# Initial Marital Status Distribution:
# SITUATION_FAMILIALE
# Marie          30193
# Celibataire     9509
#                 1518
# Veuf(ve)         508
# Divorce          337
# Name: count, dtype: int64
# Initial whitespace-only entries: 1518
#
# Final Marital Status Distribution:
# SITUATION_FAMILIALE
# Marie          30193
# Celibataire     9509
# Unknown         1518
# Veuf(ve)         508
# Divorce          337
# Name: count, dtype: int64
#
# Total 'Unknown' entries: 1518
# Rows with valid marital status: 42065/42065
# Rows with invalid marital status: 0

# %% [markdown]
# NUM_PIECE_IDENTITE Column

# %%
# Validate ID numbers
print("ID number analysis:")
print("Unique IDs:", df['NUM_PIECE_IDENTITE'].nunique())
print("Missing IDs:", df['NUM_PIECE_IDENTITE'].isnull().sum())

# Check ID format consistency
df['id_length'] = df['NUM_PIECE_IDENTITE'].astype(str).str.len()
print("ID length distribution:\n", df['id_length'].value_counts())
# Out:
# ID number analysis:
# Unique IDs: 42065
# Missing IDs: 0
# ID length distribution:
#  id_length
# 8    42065
# Name: count, dtype: int64

# %% [markdown]
# Profession Column

# %%
# Analyze professional information
professional_cols = ['LIB_SECTEUR_ACTIVITE', 'LIB_PROFESSION']

for col in professional_cols:
    print(f"\n{col} Analysis:")
    print("Missing values:", df[col].isnull().sum())
    print("Unique values:", df[col].nunique())
    print("Top 10 values:\n", df[col].value_counts().head(10))
# Out:
# LIB_SECTEUR_ACTIVITE Analysis:
# Missing values: 0
# Unique values: 31
# Top 10 values:
#  LIB_SECTEUR_ACTIVITE
# STATION  DE SERVICE                      13655
#                                           7465
# COMMERCIAL                                5346
# AGRICULTURE, CHASSE, SERVICES ANNEXES     3633
# EMPLOYÉS                                  3348
# AUCUN                                     2522
# OUVRIERS                                   923
# INDUSTRIE                                  914
# RETRAITÉS                                  724
# ÉDUCATION                                  719
# Name: count, dtype: int64
#
# LIB_PROFESSION Analysis:
# Missing values: 2801
# Unique values: 680
# Top 10 values:
#  LIB_PROFESSION
# COMMERCIAL                              5418
# NON FOURNI                              4601
# NON DEFINIE                             2520
# AGRICULTEUR                             2365
# GERANT                                  2307
# RETRAITE                                2267
# OUVRIER                                 1018
# MILITAIRE                                917
# ACTEUR DE THEATRE, ARTISTE SUR SCENE     580
# ADJOINT ADMINISTRATIF                    484
# Name: count, dtype: int64

# %% [markdown]
# Unique values in LIB_SECTEUR_ACTIVITE

# %%
df['LIB_SECTEUR_ACTIVITE'].nunique()
# Out:
# 31

# %% [markdown]
# Unique valyes in LIB_PROFESSION

# %%
df['LIB_PROFESSION'].nunique()
# Out:
# 680

# %% [markdown]
# Cleaning LIB_SECTEUR_ACTIVITE

# %%
# First, clean the missing values represented as whitespace
print("Initial analysis for LIB_SECTEUR_ACTIVITE:")
print(f"Missing (NaN): {df['LIB_SECTEUR_ACTIVITE'].isnull().sum()}")
print(f"Whitespace-only: {(df['LIB_SECTEUR_ACTIVITE'].str.strip() == '').sum()}")

# Replace whitespace-only strings with a label
mask = df['LIB_SECTEUR_ACTIVITE'].str.strip() == ''
df.loc[mask, 'LIB_SECTEUR_ACTIVITE'] = 'NON_RENSEIGNE'  

# Verify cleaning
print("\nAfter cleaning whitespace:")
print(df['LIB_SECTEUR_ACTIVITE'].value_counts().head())
# Out:
# Initial analysis for LIB_SECTEUR_ACTIVITE:
# Missing (NaN): 0
# Whitespace-only: 7465
#
# After cleaning whitespace:
# LIB_SECTEUR_ACTIVITE
# STATION  DE SERVICE                      13655
# NON_RENSEIGNE                             7465
# COMMERCIAL                                5346
# AGRICULTURE, CHASSE, SERVICES ANNEXES     3633
# EMPLOYÉS                                  3348
# Name: count, dtype: int64

# %% [markdown]
# Grouping LIB_SECTEUR_ACTIVITE into meaningful categories

# %%
secteur_list = df['LIB_SECTEUR_ACTIVITE'].unique().tolist()
secteur_list
# Out:
# ['CADRES ET PROFESSIONS INTELLECTUELLES SUPÉRIEURES',
#  'SERVICES PERSONNELS',
#  'COMMERCIAL',
#  'AUCUN',
#  'NON_RENSEIGNE',
#  'OUVRIERS',
#  'STATION  DE SERVICE',
#  'EMPLOYÉS',
#  'AGRICULTURE, CHASSE, SERVICES ANNEXES',
#  'RETRAITÉS',
#  'ARTISANS, COMMERÇANTS ET CHEFS D ENTREPRISE',
#  'PROFESSIONS INTERMÉDIAIRES',
#  'AUTRES PERSONNES SANS ACTIVITÉ PROFESSIONNELLE',
#  'ACTIVITES IARD TARIFIABLES',
#  'COMMERCE DE GROS ET INTERMÉDIAIRES DU COMMERCE',
#  'INGENIEUR',
#  'COMMERCE ET RÉPARATION AUTOMOBILE',
#  'ACTIVITE SPORTIVE',
#  'COMMERCE DE DÉTAIL ET RÉPARATION D ARTICLES DOMESTIQUES',
#  'ADMINISTRATION PUBLIQUE',
#  'ASSURANCE',
#  'EXTRACTION DE MINERAIS MÉTALLIQUES',
#  'RECHERCHE ET DÉVELOPPEMENT',
#  'SANTÉ ET ACTION SOCIALE',
#  'INDUSTRIE ',
#  'POSTES ET TÉLÉCOMMUNICATIONS',
#  'ÉDUCATION',
#  'PÊCHE, AQUACULTURE',
#  'COKÉFACTION, RAFFINAGE, INDUSTRIES NUCLÉAIRES',
#  'TRANSPORTS AÉRIENS',
#  'INDUSTRIES ALIMENTAIRES']

# %%
sector_mapping = {
    # High-income professionals (low physical risk, high asset protection needs)
    'CADRES ET PROFESSIONS INTELLECTUELLES SUPÉRIEURES': 'CADRES_SUPERIEURS',
    'INGENIEUR': 'CADRES_SUPERIEURS',
    'RECHERCHE ET DÉVELOPPEMENT': 'CADRES_SUPERIEURS',
    
    # Commercial and business activities
    'COMMERCIAL': 'COMMERCE_ET_VENTE',
    'COMMERCE DE GROS ET INTERMÉDIAIRES DU COMMERCE': 'COMMERCE_ET_VENTE',
    'COMMERCE ET RÉPARATION AUTOMOBILE': 'COMMERCE_ET_VENTE',
    'COMMERCE DE DÉTAIL ET RÉPARATION D ARTICLES DOMESTIQUES': 'COMMERCE_ET_VENTE',
    'ARTISANS, COMMERÇANTS ET CHEFS D ENTREPRISE': 'COMMERCE_ET_VENTE',
    
    # Services sector (varied risk profiles)
    'SERVICES PERSONNELS': 'SERVICES',
    'STATION DE SERVICE': 'SERVICES',
    'ACTIVITE SPORTIVE': 'SERVICES',
    'SERVICES': 'SERVICES',
    
    # Industrial and manual labor (higher physical risk)
    'OUVRIERS': 'INDUSTRIE_ET_CONSTRUCTION',
    'INDUSTRIE': 'INDUSTRIE_ET_CONSTRUCTION',
    'INDUSTRIES ALIMENTAIRES': 'INDUSTRIE_ET_CONSTRUCTION',
    'EXTRACTION DE MINERAIS MÉTALLIQUES': 'INDUSTRIE_ET_CONSTRUCTION',
    'COKÉFACTION, RAFFINAGE, INDUSTRIES NUCLÉAIRES': 'INDUSTRIE_ET_CONSTRUCTION',
    
    # Agriculture and fishing (specialized risks)
    'AGRICULTURE, CHASSE, SERVICES ANNEXES': 'AGRICULTURE_ET_PECHE',
    'PÊCHE, AQUACULTURE': 'AGRICULTURE_ET_PECHE',
    
    # Public sector and administration (stable, low risk)
    'ADMINISTRATION PUBLIQUE': 'ADMINISTRATION_PUBLIQUE',
    'POSTES ET TÉLÉCOMMUNICATIONS': 'ADMINISTRATION_PUBLIQUE',
    'EMPLOYÉS': 'ADMINISTRATION_PUBLIQUE',  # Assuming most employees are in public sector
    
    # Education and healthcare (professional services)
    'ÉDUCATION': 'EDUCATION_ET_SANTE',
    'SANTÉ ET ACTION SOCIALE': 'EDUCATION_ET_SANTE',
    'PROFESSIONS INTERMÉDIAIRES': 'EDUCATION_ET_SANTE',  # Often includes teachers, nurses, etc.
    
    # Insurance and finance (professional services)
    'ASSURANCE': 'FINANCE_ET_ASSURANCE',
    'ACTIVITES IARD TARIFIABLES': 'FINANCE_ET_ASSURANCE',  # IARD = Incendie, Accidents, Risques Divers
    
    # Transportation (higher risk)
    'TRANSPORTS AÉRIENS': 'TRANSPORTS',
    'TRANSPORTS': 'TRANSPORTS',
    
    # Special categories
    'RETRAITÉS': 'RETRAITES',
    'AUCUN': 'SANS_EMPLOI',
    'AUTRES PERSONNES SANS ACTIVITÉ PROFESSIONNELLE': 'SANS_EMPLOI',
    'NON_RENSEIGNE': 'NON_RENSEIGNE'
}

# Apply the mapping
df['SECTEUR_ACTIVITE_GROUP'] = df['LIB_SECTEUR_ACTIVITE'].map(sector_mapping)

# For any values not in our mapping, assign to 'AUTRES_SECTEURS'
df['SECTEUR_ACTIVITE_GROUP'] = df['SECTEUR_ACTIVITE_GROUP'].fillna('AUTRES_SECTEURS')

# Verify the grouping
print("Distribution of sector groups:")
print(df['SECTEUR_ACTIVITE_GROUP'].value_counts())

print(f"\nNumber of unique sector groups: {df['SECTEUR_ACTIVITE_GROUP'].nunique()}")
# Out:
# Distribution of sector groups:
# SECTEUR_ACTIVITE_GROUP
# AUTRES_SECTEURS              14569
# NON_RENSEIGNE                 7465
# COMMERCE_ET_VENTE             5883
# AGRICULTURE_ET_PECHE          3644
# ADMINISTRATION_PUBLIQUE       3639
# SANS_EMPLOI                   2859
# EDUCATION_ET_SANTE            1144
# INDUSTRIE_ET_CONSTRUCTION      947
# RETRAITES                      724
# CADRES_SUPERIEURS              666
# SERVICES                       333
# FINANCE_ET_ASSURANCE           151
# TRANSPORTS                      41
# Name: count, dtype: int64
#
# Number of unique sector groups: 13

# %% [markdown]
# LIB_PROFESSION

# %%
profession_list = df['LIB_PROFESSION'].unique().tolist()
profession_list
# Out:
# ['MÉDECINS LIBÉRAUX GÉNÉRALISTES',
#  'CHAUFFEUR',
#  'COMMERCIAL',
#  'NON DEFINIE',
#  'ETUDIANTE',
#  'AUTRES OUVRIERS QUALIFIÉS DES TRAVAUX PUBLICS',
#  'OUVRIERS QUALIFIÉS D ENTRETIEN GÉNÉRAL DES BÂTIMENTS',
#  'INSPECTEUR',
#  'AGENTS ADMINISTRATIFS DE LA FONCTION PUBLIQUE (Y.C. ENSEIGNEMENT)',
#  'CONDUCTEURS DE VÉHICULE ROUTIER DE TRANSPORT EN COMMUN (SALARIÉS)',
#  'AGRICULTEURS SUR PETITE EXPLOITATION DE CÉRÉALES-GRANDES CULTURES',
#  'AGRICULTEURS SUR GRANDE EXPLOITATION DE CÉRÉALES-GRANDES CULTURES',
#  'AGRICULTEURS SUR MOYENNE EXPLOITATION SANS ORIENTATION DOMINANTE',
#  'EMPLOYÉS DES SERVICES COMMERCIAUX DE LA BANQUE',
#  'AGRICULTEURS SUR PETITE EXPLOITATION SANS ORIENTATION DOMINANTE',
#  'EMPLOYÉS ADMINISTRATIFS QUALIFIÉS DES AUTRES SERVICES DES ENTREPRISES',
#  'EMPLOYÉS QUALIFIÉS DES SERVICES COMMERCIAUX DES ENTREPRISES (HORS VENTE)',
#  'ANCIENS EMPLOYÉS',
#  'ARTISANS DIVERS DE FABRICATION DE MACHINES',
#  'AUTRES AGENTS ET OUVRIERS QUALIFIÉS (SÉDENTAIRES) DES SERVICES D EXPLOITATION DES TRANSPORTS',
#  'PROFESSEURS AGRÉGÉS ET CERTIFIÉS DE L ENSEIGNEMENT SECONDAIRE',
#  'CONDUCTEURS DE VÉHICULE DE RAMASSAGE DES ORDURES MÉNAGÈRES',
#  'AGRICULTEURS SUR MOYENNE EXPLOITATION DE CÉRÉALES-GRANDES CULTURES',
#  'ADJOINTS ADMINISTRATIFS DES COLLECTIVITÉS LOCALES',
#  'AGENTS IMMOBILIERS INDÉPENDANTS, DE 0 À 9 SALARIÉS',
#  'EMPLOYÉS DES SERVICES TECHNIQUES DES ORGANISMES DE SÉCURITÉ SOCIALE ET ASSIMILÉS',
#  'TRANSPORTEURS INDÉPENDANTS ROUTIERS ET FLUVIAUX, DE 0 À 9 SALARIÉS',
#  'EMPLOYÉS NON QUALIFIÉS DES SERVICES COMPTABLES OU FINANCIERS',
#  'EMPLOYÉS ADMINISTRATIFS DES SERVICES TECHNIQUES DE LA BANQUE',
#  'CADRES ADMINISTRATIFS DE FRANCE TÉLÉCOM (STATUT PUBLIC)',
#  'OUVRIERS AGRICOLES SANS SPÉCIALISATION PARTICULIÈRE',
#  'AGENTS ADMINISTRATIFS DE L ETAT ET ASSIMILÉS (SAUF POSTE, FRANCE TÉLÉCOM)',
#  'ADJOINTS ADMINISTRATIFS DE L ETAT ET ASSIMILÉS (SAUF POSTE, FRANCE TÉLÉCOM)',
#  'SECRÉTAIRES',
#  'EMPLOYÉS DE LA POSTE',
#  'AGENTS DE SERVICE DES AUTRES ÉTABLISSEMENTS D ENSEIGNEMENT',
#  nan,
#  'ANCIENS OUVRIERS',
#  'EMPLOYÉS DE LIBRE SERVICE DU COMMERCE ET MAGASINIERS',
#  'AGENTS DES SERVICES COMMERCIAUX DES TRANSPORTS DE VOYAGEURS ET DU TOURISME',
#  'EMPLOYÉS DES SERVICES TECHNIQUES DES ASSURANCES',
#  'AGENTS NON QUALIFIÉS DES SERVICES D EXPLOITATION DES TRANSPORTS',
#  'VENDEURS DE TABAC, PRESSE ET ARTICLES DIVERS',
#  'EMPLOYÉS D ÉTAGE ET EMPLOYÉS POLYVALENTS DE L HÔTELLERIE',
#  'EXPLOITANTS FORESTIERS INDÉPENDANTS, DE 0 À 9 SALARIÉS',
#  'ADJOINTS ADMINISTRATIFS DE LA FONCTION PUBLIQUE (Y.C. ENSEIGNEMENT)',
#  'EMPLOYÉS QUALIFIÉS DES SERVICES DU PERSONNEL ET DES SERVICES JURIDIQUES',
#  'ANCIENS CADRES',
#  'EMPLOYÉS QUALIFIÉS DES SERVICES COMPTABLES OU FINANCIERS',
#  'EMPLOYÉS ADMINISTRATIFS D EXPLOITATION DES TRANSPORTS DE MARCHANDISES',
#  'ADJOINTS ADMINISTRATIFS DES HÔPITAUX PUBLICS',
#  'EMPLOYÉS ADMINISTRATIFS DIVERS D ENTREPRISES',
#  'AGENTS ADMINISTRATIFS DES HÔPITAUX PUBLICS',
#  'AGENTS D ACCUEIL NON QUALIFIÉS',
#  'AGENTS DE CONSTATATION OU DE RECOUVREMENT DES IMPÔTS, DU TRÉSOR, DES DOUANES',
#  'VENDEURS EN GROS DE BIENS D ÉQUIPEMENT, BIENS INTERMÉDIAIRES',
#  'ARTISANS DE LA PEINTURE ET DES FINITIONS DU BÂTIMENT',
#  'ARTISANS CHAUDRONNIERS',
#  'CADRES DES MARCHÉS FINANCIERS',
#  'CADRES DES SERVICES FINANCIERS OU COMPTABLES DES GRANDES ENTREPRISES',
#  'CHEFS DE GRANDE ENTREPRISE DE 500 SALARIÉS ET PLUS',
#  'EMPLOYÉS DES SERVICES COMPTABLES OU FINANCIERS',
#  'OUVRIERS DE L ÉLEVAGE',
#  'AGENTS ADMINISTRATIFS DES COLLECTIVITÉS LOCALES',
#  'AGRICULTEURS SUR GRANDE EXPLOITATION SANS ORIENTATION DOMINANTE',
#  'AGENTS DE SERVICE DES ÉTABLISSEMENTS PRIMAIRES',
#  'SERGENTS ET SOUS-OFFICIERS DE GRADE ÉQUIVALENT DES ARMÉES (SAUF POMPIERS MILITAIRES)',
#  'AGENTS QUALIFIÉS DE LABORATOIRE (SAUF CHIMIE, SANTÉ)',
#  'ELEVEURS D HERBIVORES, SUR GRANDE EXPLOITATION',
#  'MÉCANICIENS QUALIFIÉS DE MAINTENANCE, ENTRETIEN : ÉQUIPEMENTS NON INDUSTRIELS',
#  'VENDEURS DU COMMERCE DE FLEURS',
#  'AGENTS DE MAÎTRISE EN CONSTRUCTION MÉCANIQUE, TRAVAIL DES MÉTAUX',
#  'ELEVEURS D HERBIVORES SUR MOYENNE EXPLOITATION',
#  'INGÉNIEURS DE L ETAT (Y.C. INGÉNIEURS MILITAIRES) ET ASSIMILÉS',
#  'AUTRES VENDEURS NON SPÉCIALISÉS',
#  'ELÈVES, ÉTUDIANTS',
#  'AUTRES OUVRIERS DE PRODUCTION QUALIFIÉS NE TRAVAILLANT PAS SUR MACHINE : INDUSTRIE AGROALIMENTAIRE (',
#  'ARCHITECTES LIBÉRAUX',
#  'CADRES DE L HÔTELLERIE ET DE LA RESTAURATION',
#  'CADRES DES SERVICES FINANCIERS OU COMPTABLES DES PETITES ET MOYENNES ENTREPRISES',
#  'ARTISANS DE L AMEUBLEMENT',
#  'MÉDECINS HOSPITALIERS SANS ACTIVITÉ LIBÉRALE',
#  'ELEVEURS',
#  'AUTRES OPÉRATEURS ET OUVRIERS QUALIFIÉS : MÉTALLURGIE, PRODUCTION VERRIÈRE, MATÉRIAUX DE CONSTRUCTIO',
#  'CHARPENTIERS EN BOIS QUALIFIÉS',
#  'CHÔMEURS N AYANT JAMAIS TRAVAILLÉ',
#  'AGENTS DE POLICE DE L ETAT',
#  'CHEFS D ENTREPRISE DU BÂTIMENT ET DES TRAVAUX PUBLICS, DE 10 À 49 SALARIÉS',
#  'INGÉNIEURS ET CADRES SPÉCIALISTES DES TÉLÉCOMMUNICATIONS',
#  'INDÉPENDANTS GESTIONNAIRES DE SPECTACLE OU DE SERVICE RÉCRÉATIF, DE 0 À 9 SALARIÉS',
#  'TECHNICIENS MÉDICAUX',
#  'ARTISANS D ART',
#  'ANCIENNES PROFESSIONS INTERMÉDIAIRES',
#  'OUVRIERS DE PRODUCTION NON QUALIFIÉS : CHIMIE, PHARMACIE, PLASTURGIE',
#  'AVOCATS',
#  'MAÇONS QUALIFIÉS',
#  'CONTRÔLEURS DES TRANSPORTS (PERSONNELS ROULANTS)',
#  'DÉTAILLANTS EN TABAC, PRESSE ET ARTICLES DIVERS, DE 0 À 9 SALARIÉS',
#  'ENTREPRENEURS EN PARCS ET JARDINS, PAYSAGISTES',
#  'COMMERCE DE FROS ET INTERMEDIAIRES DU COMMERCE',
#  'AUTRES PROFESSIONS INTERMÉDIAIRES COMMERCIALES (SAUF TECHNICIENS DES FORCES DE VENTE)',
#  'EMPLOYÉS DES SERVICES DIVERS',
#  'AUTRES OUVRIERS DE PRODUCTION NON QUALIFIÉS : INDUSTRIE AGRO-ALIMENTAIRE',
#  'ENSEIGNANTS DE L ENSEIGNEMENT SUPÉRIEUR',
#  'AUTRES MÉCANICIENS OU AJUSTEURS QUALIFIÉS (OU SPÉCIALITÉ NON RECONNUE)',
#  'AUTRES PERSONNELS ADMINISTRATIFS DE CATÉGORIE A DE L ETAT (HORS ENSEIGNEMENT, PATRIMOINE, IMPÔTS, TR',
#  'INGÉNIEURS ET CADRES D ÉTUDE ET DÉVELOPPEMENT DE L AGRICULTURE, LA PÊCHE, LES EAUX ET FORÊTS',
#  'INSPECTEURS ET AUTRES PERSONNELS DE CATÉGORIE A DES IMPÔTS, DU TRÉSOR ET DES DOUANES',
#  'ALLOCATAIRES DE LA RECHERCHE PUBLIQUE',
#  'PROFESSEURS ET MAÎTRES DE CONFÉRENCES',
#  'PERSONNES DIVERSES SANS ACTIVITÉ PROFESSIONNELLE DE 60 ANS ET PLUS (SAUF RETRAITES)',
#  'AUTRES INDÉPENDANTS DIVERS PRESTATAIRES DE SERVICES, DE 0 À 9 SALARIÉS',
#  'OUVRIERS QUALIFIÉS DIVERS DE TYPE INDUSTRIEL',
#  'PATRONS PÊCHEURS ET AQUACULTEURS, DE 0 À 9 SALARIÉS',
#  'AGENTS DES POLICES MUNICIPALES',
#  'AUTRES AGENTS ET HÔTESSES D ACCOMPAGNEMENT (TRANSPORTS, TOURISME)',
#  'CHEFS D ENTREPRISE COMMERCIALE, DE 10 À 49 SALARIÉS',
#  'CHEFS D ENTREPRISE DE SERVICES, DE 10 À 49 SALARIÉS',
#  'AUXILIAIRES DE PUÉRICULTURE',
#  'AGRICULTEUR',
#  'PROFESSIONS INTERMÉDIAIRES TECHNIQUES ET COMMERCIALES DES ASSURANCES',
#  'TAILLEURS ET COUTURIÈRES QUALIFIÉS, OUVRIERS QUALIFIÉS DU TRAVAIL DES ÉTOFFES (SAUF FABRICATION DE V',
#  'STANDARDISTES, TÉLÉPHONISTES',
#  'ARTISANS DES SERVICES DIVERS, DE 0 À 9 SALARIÉS',
#  'AGENTS DE SERVICE DE LA FONCTION PUBLIQUE (SAUF ÉCOLES, HÔPITAUX)',
#  'SURVEILLANTS DE L ADMINISTRATION PÉNITENTIAIRE',
#  'OUVRIERS QUALIFIÉS DE LA MANUTENTION, CONDUCTEURS DE CHARIOTS ÉLÉVATEURS, CARISTES',
#  'APPRENTIS BOULANGERS, BOUCHERS, CHARCUTIERS',
#  'EXPLOITANTS DE PETIT RESTAURANT, CAFÉ-RESTAURANT, DE 0 À 2 SALARIÉS',
#  'AGENTS GÉNÉRAUX ET COURTIERS D ASSURANCE INDÉPENDANTS, DE 0 À 9 SALARIÉS',
#  'AGRICULTEURS',
#  'DIRECTEURS TECHNIQUES DES GRANDES ENTREPRISES',
#  'OUVRIERS D ART',
#  'PERSONNES DIVERSES SANS ACTIVITÉ PROFESSIONNELLE DE MOINS DE 60 ANS (SAUF RETRAITES)',
#  'MAGASINS D ACCESSOIRES,EQUIPEMENT,PECES DETACHEES ET DE PRODUITS POUR AUTOMOBILE',
#  'CHEFS DE PROJETS INFORMATIQUES, RESPONSABLES INFORMATIQUES',
#  'CHAUSSURES (COMMERCE)',
#  'AGENCES (BUREAUX DE REPRESENTATION)',
#  'ARBITRE DES SPORTS COLLECTIFS',
#  'MENUISERIES (FABRICATION)',
#  'ACHETEURS NON CLASSÉS CADRES, AIDES-ACHETEURS',
#  'EDUCATEURS SPÉCIALISÉS',
#  'CADRES CHARGÉS D ÉTUDES ÉCONOMIQUES, FINANCIÈRES, COMMERCIALES',
#  'MAGASINS D EXPOSITIONS SANS VENTE D ACCESOIRES',
#  'PATISSERIE GLACIERS',
#  'OUVRIERS DU TRI, DE L EMBALLAGE, DE L EXPÉDITION, NON QUALIFIÉS',
#  'CADRES DES OPÉRATIONS BANCAIRES',
#  'EDUCATEURS TECHNIQUES SPÉCIALISÉS, MONITEURS D ATELIER',
#  'MILITAIRES DU CONTINGENT',
#  'OUVRIER',
#  'BOUCHERIE',
#  'ARTISTES DRAMATIQUES',
#  'MÉDECINS LIBÉRAUX SPÉCIALISTES',
#  'CADRES CEDENTAIRES',
#  'COMMERCE DE BALANCES ET APPAREILS SIMILAIRES',
#  'ELECTRICITE (VENTE ET POSE)',
#  'ASSISTANTS DE SERVICE SOCIAL',
#  'AGENTS DE SERVICE HOSPITALIERS (DE LA FONCTION PUBLIQUE OU DU SECTEUR PRIVÉ)',
#  'AUTOMOBILES (MAGASINS D ACCESSOIRES, D EQUIPEMENTS, DE PIECES DETACHEES ET DE PRODUIT POUR L AUTOMOBILE)',
#  'CHEFS D ENTREPRISE DE L INDUSTRIE OU DES TRANSPORTS, DE 10 À 49 SALARIÉS',
#  'ACTEUR DE THEATRE, ARTISTE SUR SCENE',
#  'EMPLOYÉS ADMINISTRATIFS NON QUALIFIÉS',
#  'RESPONSABLES D EXPLOITATION DES TRANSPORTS DE VOYAGEURS ET DE MARCHANDISES (NON CADRES)',
#  'ASSISTANTS DE LA PUBLICITÉ, DES RELATIONS PUBLIQUES (INDÉPENDANTS OU SALARIÉS)',
#  'AGENTS DE MAÎTRISE EN FABRICATION DE MATÉRIEL ÉLECTRIQUE, ÉLECTRONIQUE',
#  'EXPERTS SALARIÉS OU INDÉPENDANTS DE NIVEAU TECHNICIEN, TECHNICIENS DIVERS',
#  'AIDES DE CUISINE, APPRENTIS DE CUISINE ET EMPLOYÉS POLYVALENTS DE LA RESTAURATION',
#  'CADRES DES RELATIONS PUBLIQUES ET DE LA COMMUNICATION',
#  'INGÉNIEURS ET CADRES D ÉTUDE, RECHERCHE ET DÉVELOPPEMENT DES AUTRES INDUSTRIES (IMPRIMERIE, MATÉRIAU',
#  'ANCIENS ARTISANS, COMMERÇANTS, CHEFS D ENTREPRISE',
#  'CADRES COMMERCIAUX DES GRANDES ENTREPRISES (HORS COMMERCE DE DÉTAIL)',
#  'ELECTRONIQUE , REPARATION ET VENTE(PIECE DETACHEES, MATERIELS ET FOURNITURES)',
#  'AGENTS DE MAÎTRISE EN MAINTENANCE, INSTALLATION EN ÉLECTROMÉCANIQUE',
#  'NETTOYAGE (SOCIETE DE SERVICE)',
#  'ATLIER DE REPARATION',
#  'AGENTS DE MAÎTRISE EN ENTRETIEN GÉNÉRAL, INSTALLATION, TRAVAUX NEUFS (HORS MÉCANIQUE, ÉLECTROMÉCANIQ',
#  'OUVRIERS QUALIFIÉS DES AUTRES INDUSTRIES (EAU, GAZ, ÉNERGIE, CHAUFFAGE)',
#  'TECHNICIENS DE PRODUCTION ET DE CONTRÔLE-QUALITÉ DES INDUSTRIES DE TRANSFORMATION',
#  'AGENTS D ACCUEIL QUALIFIÉS, HÔTESSES D ACCUEIL ET D INFORMATION',
#  'EDUCATEURS DE JEUNES ENFANTS',
#  'LIBRAIRIE, BIBLIOTHEQUES',
#  'CHARGÉS DE CLIENTÈLE BANCAIRE',
#  'INGÉNIEURS ET CADRES TECHNICO-COMMERCIAUX EN BÂTIMENT, TRAVAUX PUBLICS',
#  'ECOLIER - ELEVE',
#  'POLICE',
#  'CADRES DES SERVICES TECHNIQUES DES ASSURANCES',
#  'ADJUDANTS-CHEFS, ADJUDANTS ET SOUS-OFFICIERS DE RANG SUPÉRIEUR DE L ARMÉE ET DE LA GENDARMERIE',
#  'CONCIERGES, GARDIENS D IMMEUBLES',
#  'AGENT GENERAL',
#  'VENDEURS EN HABILLEMENT ET ARTICLES DE SPORT',
#  'AUTOMOBILES (GARAGES, PARKINGS)',
#  'OFFICIES DES DOUANES TUNISIENNES',
#  'CADRES COMMERCIAUX DE LA BANQUE',
#  'CAFE,SALON DE THE',
#  'OUVRIERS QUALIFIÉS DU TRAVAIL DU BÉTON',
#  'CUISINIERS ET COMMIS DE CUISINE',
#  'AGENTS DE MAÎTRISE EN FABRICATION DES AUTRES INDUSTRIES (IMPRIMERIE, MATÉRIAUX SOUPLES, AMEUBLEMENT',
#  'SECRÉTAIRES DE DIRECTION, ASSISTANTS DE DIRECTION (NON CADRES)',
#  'PROFESSEUR UNIVERSITAIRE',
#  'OUVRIERS QUALIFIÉS DIVERS DE TYPE ARTISANAL',
#  'ARTISANS MAÇONS',
#  'CONDUCTEURS DE VOITURE PARTICULIÈRE (SALARIÉS)',
#  'PROFESSEURS D ENSEIGNEMENT GÉNÉRAL DES COLLÈGES',
#  'VENDEURS NON SPÉCIALISÉS',
#  'TECHNICIENS DES TÉLÉCOMMUNICATIONS ET DE L INFORMATIQUE DES RÉSEAUX',
#  'TECHNICIENS D ÉTUDE ET DE CONSEIL EN AGRICULTURE, EAUX ET FORÊT',
#  'PROFESSEURS DE LYCÉE PROFESSIONNEL',
#  'OUVRIERS NON QUALIFIÉS DIVERS DE TYPE INDUSTRIEL',
#  'OUVRIERS DE PRODUCTION NON QUALIFIÉS DU TEXTILE ET DE LA CONFECTION, DE LA TANNERIE-MÉGISSERIE ET DU',
#  'OUVRIERS NON QUALIFIÉS DE MONTAGE, CONTRÔLE EN MÉCANIQUE ET TRAVAIL DES MÉTAUX',
#  'CADRES D INSPECTION, REPRESENTANT COMMERCIAUX, DELEGUES MEDICAUX',
#  'OUVRIERS DE PRODUCTION NON QUALIFIÉS : MÉTALLURGIE, PRODUCTION VERRIÈRE, CÉRAMIQUE, MATÉRIAUX DE CON',
#  'OUVRIERS NON QUALIFIÉS DIVERS DE TYPE ARTISANAL',
#  'OUVRIERS DU TRAVAIL DU BÉTON',
#  'CADRES DE L EXPLOITATION DES MAGASINS DE VENTE DU COMMERCE DE DÉTAIL',
#  'TECHNICIENS D INSTALLATION ET DE MAINTENANCE DES ÉQUIPEMENTS INDUSTRIELS (ÉLECTRIQUES, ÉLECTROMÉCANI',
#  'INSTITUTEURS',
#  'OFFICIERS DES ARMÉES ET DE LA GENDARMERIE (SAUF OFFICIERS GÉNÉRAUX)',
#  'MACONS QUALIFIES',
#  'MAGASINIERS QUALIFIÉS',
#  'OUVRIERS NON QUALIFIÉS DU SECOND OEUVRE DU BÂTIMENT',
#  'BOUCHERS (SAUF INDUSTRIE DE LA VIANDE)',
#  'ARTISANS DU TRAVAIL MÉCANIQUE DU BOIS',
#  'CONDUCTEURS DE TAXI (SALARIÉS)',
#  'PROFESSEURS DES ÉCOLES',
#  'AGENTS CIVILS DE SÉCURITÉ ET DE SURVEILLANCE',
#  'EPICERIES',
#  'TECHNICIENS DE FABRICATION ET DE CONTRÔLE-QUALITÉ EN ÉLECTRICITÉ, ÉLECTROMÉCANIQUE ET ÉLECTRONIQUE',
#  'INFIRMIERS EN SOINS GÉNÉRAUX, SALARIÉS',
#  'AGENTS DE MAÎTRISE ET TECHNICIENS EN PRODUCTION ET DISTRIBUTION D ÉNERGIE, EAU, CHAUFFAGE',
#  'OUVRIERS QUALIFIÉS DU TRAVAIL DE LA PIERRE',
#  'TECHNICIENS COMMERCIAUX ET TECHNICO-COMMERCIAUX, REPRÉSENTANTS AUPRÈS DE PARTICULIERS (HORS BANQUE,',
#  'INTERMÉDIAIRES INDÉPENDANTS DU COMMERCE, DE 0 À 9 SALARIÉS',
#  'EMPLOYÉS ET OPÉRATEURS D EXPLOITATION EN INFORMATIQUE',
#  'AUTRES OPÉRATEURS ET OUVRIERS QUALIFIÉS DE L INDUSTRIE AGRICOLE ET ALIMENTAIRE (HORS TRANSFORMATION',
#  'OUVRIERS QUALIFIÉS ET AGENTS QUALIFIÉS DE LABORATOIRE : AGROALIMENTAIRE, CHIMIE, BIOLOGIE, PHARMACIE',
#  'OUVRIERS NON QUALIFIÉS DES TRAVAUX PUBLICS ET DU TRAVAIL DU BÉTON',
#  'NON FOURNI',
#  'AGENTS DE VOYAGE ET AUXILIAIRES DE TRANSPORTS INDÉPENDANTS, DE 0 À 9 SALARIÉS',
#  'ELECTRICIENS QUALIFIÉS DE TYPE ARTISANAL (Y.C. BÂTIMENT)',
#  'QUINCAILLERIE',
#  'OUVRIERS DE PRODUCTION NON QUALIFIÉS DE L IMPRIMERIE, PRESSE, ÉDITION',
#  'RECHERCHE ET DEVELOPPEMENT',
#  'EMPLOYE A L ETRANGER',
#  'DESSINATEURS EN ÉLECTRICITÉ, ÉLECTROMÉCANIQUE ET ÉLECTRONIQUE',
#  'INGÉNIEURS ET CADRES DES MÉTHODES DE PRODUCTION',
#  'INGÉNIEURS ET CADRES D ADMINISTRATION, MAINTENANCE, SUPPORT ET SERVICES AUX UTILISATEURS EN INFORMAT',
#  'CADRES SPÉCIALISTES DE LA FORMATION',
#  'MASSEURS-KINÉSITHÉRAPEUTES RÉÉDUCATEURS, LIBÉRAUX',
#  'COIFFURE',
#  'FORMATEURS ET ANIMATEURS DE FORMATION CONTINUE',
#  'GÉOMÈTRES-EXPERTS, HUISSIERS DE JUSTICE, OFFICIERS MINISTÉRIELS, PROFESSIONS LIBÉRALES DIVERSES',
#  'INGÉNIEURS CONSEILS LIBÉRAUX EN ÉTUDES TECHNIQUES',
#  'BIJOUTERIE',
#  'RESPONSABLES COMMERCIAUX ET ADMINISTRATIFS DES TRANSPORTS DE MARCHANDISES (NON CADRES)',
#  'CADRES DES AUTRES SERVICES ADMINISTRATIFS DES PETITES ET MOYENNES ENTREPRISES',
#  'INGÉNIEURS ET CADRES D ÉTUDE, RECHERCHE ET DÉVELOPPEMENT DE LA DISTRIBUTION D ÉNERGIE, EAU',
#  'PEINTRES ET OUVRIERS QUALIFIÉS DE POSE DE REVÊTEMENTS SUR SUPPORTS VERTICAUX',
#  'TECHNICIENS DE L ENVIRONNEMENT ET DU TRAITEMENT DES POLLUTIONS',
#  'OPTICIENS LUNETIERS ET AUDIOPROTHÉSISTES (INDÉPENDANTS ET SALARIÉS)',
#  'DÉTAILLANTS EN HABILLEMENT ET ARTICLES DE SPORT, DE 0 À 9 SALARIÉS',
#  'CADRES DES AUTRES SERVICES ADMINISTRATIFS DES GRANDES ENTREPRISES',
#  'CONDUCTEURS DE TAXIS, AMBULANCIERS ET AUTRES ARTISANS DU TRANSPORT, DE 0 À 9 SALARIÉS',
#  'TECHNICIENS DE RECHERCHE-DÉVELOPPEMENT ET DES MÉTHODES DE FABRICATION EN CONSTRUCTION MÉCANIQUE ET T',
#  'BOULANGERIE, PATISSRIE...',
#  'SERVEURS, COMMIS DE RESTAURANT, GARÇONS QUALIFIÉS',
#  'CADRES D ÉTAT-MAJOR ADMINISTRATIFS, FINANCIERS, COMMERCIAUX DES GRANDES ENTREPRISES',
#  'HOTEL (PERSONNEL)',
#  'CADRES DE L ORGANISATION OU DU CONTRÔLE DES SERVICES ADMINISTRATIFS ET FINANCIERS',
#  'AUTRES SPÉCIALISTES DE LA RÉÉDUCATION, SALARIÉS',
#  'INGÉNIEURS ET CADRES DES ACHATS ET APPROVISIONNEMENTS INDUSTRIELS',
#  'TECHNICIENS DE L INDUSTRIE DES MATÉRIAUX SOUPLES, DE L AMEUBLEMENT ET DU BOIS',
#  'EXPERTS COMPTABLES, COMPTABLES AGRÉÉS, LIBÉRAUX',
#  'SURVEILLANTS ET AIDES-ÉDUCATEURS DES ÉTABLISSEMENTS D ENSEIGNEMENT',
#  'TECHNICIENS D INSTALLATION, DE MAINTENANCE, SUPPORT ET SERVICES AUX UTILISATEURS EN INFORMATIQUE',
#  'CONDUCTEURS ROUTIERS ET GRANDS ROUTIERS (SALARIÉS)',
#  'CADRES COMMERCIAUX DES PETITES ET MOYENNES ENTREPRISES (HORS COMMERCE DE DÉTAIL)',
#  'OUVRIERS DU MARAÎCHAGE OU DE L HORTICULTURE',
#  'MAGISTRATS',
#  'OUVRIERS DE PRODUCTION NON QUALIFIÉS DE LA TRANSFORMATION DES VIANDES',
#  'OUVRIERS DES TRAVAUX PUBLICS EN INSTALLATIONS ÉLECTRIQUES ET DE TÉLÉCOMMUNICATIONS',
#  'CAISSIERS DE MAGASIN',
#  'OPÉRATEURS QUALIFIÉS SUR MACHINE DE SOUDAGE',
#  'ouvrier décorateur de batiment',
#  'TECHNICIENS D INSTALLATION ET DE MAINTENANCE DES ÉQUIPEMENTS NON INDUSTRIELS (HORS INFORMATIQUE ET T',
#  'MAÎTRES AUXILIAIRES ET PROFESSEURS CONTRACTUELS DE L ENSEIGNEMENT SECONDAIRE',
#  'AIDE SOIGNANT',
#  'TECHNICIENS COMMERCIAUX ET TECHNICO-COMMERCIAUX, REPRÉSENTANTS EN SERVICES AUPRÈS D ENTREPRISES OU D',
#  'INGÉNIEURS ET CADRES D ÉTUDE, RECHERCHE ET DÉVELOPPEMENT EN ÉLECTRICITÉ, ÉLECTRONIQUE',
#  'ELECTRICIENS, ÉLECTRONICIENS QUALIFIÉS EN MAINTENANCE ENTRETIEN, RÉPARATION : AUTOMOBILE',
#  'AGENTS DE MAÎTRISE EN FABRICATION : MÉTALLURGIE, MATÉRIAUX LOURDS ET AUTRES INDUSTRIES DE TRANSFORMA',
#  'INFORMATIQUES (COMMERCES DE MATERIELS)',
#  'OUVRIERS NON QUALIFIÉS DE L ASSAINISSEMENT ET DU TRAITEMENT DES DÉCHETS',
#  'COUTURE (ATELIER DE )',
#  'DIRECTEURS, RESPONSABLES DE PROGRAMMATION ET DE PRODUCTION DE L AUDIOVISUEL ET DES SPECTACLES',
#  'OUVRIERS DE PRODUCTION NON QUALIFIÉS : INDUSTRIE LOURDE DU BOIS, FABRICATION DES PAPIERS ET CARTONS',
#  'INGÉNIEURS D ÉTUDE ET DE RECHERCHE DE LA RECHERCHE PUBLIQUE',
#  'TECHNICIENS COMMERCIAUX ET TECHNICO-COMMERCIAUX, REPRÉSENTANTS EN BIENS D ÉQUIPEMENT, EN BIENS INTER',
#  'DOUANE',
#  'AIDES-MINEURS, OUVRIERS NON QUALIFIÉS DE L EXTRACTION',
#  'GERANT',
#  'BANQUIER',
#  'AVOCAT',
#  'DIRECTEUR',
#  'JOURNALISTE',
#  'ADMINISTRATEUR',
#  'MEDECIN',
#  'COMMERCANT(E)',
#  'EXPERT COMPTABLE',
#  'COMMERCANT',
#  'ASSISTANT COMMERCIAL',
#  'RETRAITE',
#  'COMPTABLE',
#  'PROFESSEUR',
#  'TECHNICIEN SUPERIEUR',
#  'STEWART',
#  'CADRE',
#  'REDACTEUR',
#  'CHEF SERVICE FINANCIER',
#  'DENTISTE',
#  'INSTITUTRICE',
#  'ENSEIGNANT',
#  'INFORMATICIEN',
#  'SECRETAIRE',
#  'CHEF DE SERVICE',
#  'INGENIEUR',
#  'CHEF DE DIVISION',
#  'ASSISTANTE',
#  'INFORMATICIENNE',
#  'AUDITEUR INTERNE',
#  'RESPONSABLE ACHAT',
#  'INGENIEUR INFORMATICIEN',
#  'PROFESSEUR D ENSEIGNEMENT TECHNIQUE',
#  'CHEF DE SERVICE PRINCIPAL',
#  'JUGE',
#  'AVOCATE',
#  'PROGRAMMEUR',
#  'INGENIEUR PRINCIPAL',
#  'FORMATEUR',
#  'FEMME D AFFAIRE',
#  'DIRECTEUR GENERAL',
#  'PHARMACIENNE',
#  'ASSISTANT DE GESTION',
#  'HOMME D AFFAIRE',
#  'ELECTRICIEN',
#  'EMPLOYE(E)  BH',
#  'FONDE DE POUVOIR',
#  'ASSUREUR',
#  'TECHNICIEN',
#  'SECRETAIRE D ADMINISTRATION',
#  'STANDARDISTE',
#  'ETUDIANT',
#  'CHEF D ENTREPRISE',
#  'AIDE ANIMATRICE',
#  'STYLISTE MODELISTE',
#  'PREPARATEUR EN PHARMACIE',
#  'AGENT',
#  'OPERATEUR',
#  'AGENT CADRE',
#  'CONSEILLE',
#  'INFIRMIER',
#  'ARTISTE',
#  'EMPLOYE STUSID BANK',
#  'EMPLOYE DE BANQUE',
#  'AGENT ADMINISTRATIVE',
#  'CONTROLEUR',
#  'TECHNOLOGUE',
#  'TAXISTE',
#  'CHEF D AGENCE',
#  'DIRECTEUR FINANCIER',
#  'OFFICIER MILITAIRE',
#  'CAISSIER',
#  'ENSEIGNANTE',
#  'EMPLOYER',
#  'ASSISTANTE ENSEIGNEMENT SUPERIEUR',
#  'AGENT D ACCUEIL',
#  'CHEF DE RESERVATION',
#  'PILOTE DE LIGNE',
#  'INSTITUTEUR',
#  'MAGASINIER',
#  'AGENT DE L O.A.C.A',
#  'SERVEUR',
#  'GARDE NATIONAL',
#  'INSPECTEUR EN CHEF',
#  'ATTACHE DE DIRECTION',
#  'DIRECTEUR FINANCIER ET COMPTABLE',
#  'ANALYSTE',
#  'GESTIONNAIRE',
#  'MILITAIRE',
#  'MAGISTRAT',
#  'ASSISTANT ADMINISTRATIF',
#  'CHEF DE SECTION',
#  'PHOTOGRAPHE',
#  'ADJOINT TECHNIQUE',
#  'SOUS DIRECTEUR',
#  'AGENT DE BUREAU',
#  'ADJOINT ADMINISTRATIF',
#  'AGENT TECHNIQUE',
#  'SURVEILLANT',
#  'INDUSTRIEL',
#  'ARCHITECTE',
#  'DIRECTEUR COMMERCIAL',
#  'COIFFEUSE',
#  'AGENT QUALIFIE',
#  'ORTHODENTISTE',
#  'ADJOINT COMPTABLE',
#  'AIDE COMMERCANTE',
#  'IMPRIMEUR',
#  'INSPECTEUR PRINCIPAL DE POLICE',
#  'ANESTHESISTE',
#  'HOTESSE DE L AIR',
#  'CHEF DE BUREAU',
#  'ASSISTANTE ADMINISTRATIVE',
#  'PATISSIERE',
#  'OUVRIER SPECIALISE',
#  'ATTACHE D ADMINISTRATION',
#  'OFFICIER DE MARINE',
#  'TAILLEUR',
#  'CHEF D EQUIPE',
#  'INGENIEUR AGRONOME',
#  'CONDUCTEUR',
#  'CONTROLEUR AERIEN',
#  'TRANSPORTEUR',
#  'ATTACHE TECHNICIEN',
#  'OPTICIEN',
#  'MONITEUR',
#  'ASSISTANT',
#  'AGENT DE GESTION',
#  'MENUISIER',
#  'CONTROLEUR AVIATION CIVILE',
#  'GARDIEN',
#  'ATTACHÉ(E) D INSPECTION',
#  'BIOLOGISTE',
#  'AGENT D INFORMATIQUE',
#  'CONSULAT',
#  'INGENIEUR EN INFORMATIQUE',
#  'OFFICIER CONTROLEUR DE LA CIRCULATION AERIENNE',
#  'PEINTRE',
#  'ARTISANS COIFFEURS, MANUCURES, ESTHÉTICIENS, DE 0 À 9 SALARIÉS',
#  'COUTURIERE',
#  'DIRECTEUR D HOTEL',
#  'DIRECTEUR CENTRAL',
#  'MAITRE ASSISTANT',
#  'MECANICIEN',
#  'SAPEUR POMPIER PROFESSIONNEL',
#  'CHEF D ATELIER',
#  'AGENCE DE VOYAGE',
#  'CHEF PATISSIER',
#  'KINESITHERAPEUTE',
#  'ARTISANT(E)',
#  'ADJOINT DE GESTION',
#  'PRESIDENT DIRECTEUR GENERAL',
#  'INSPECTEUR DE L ENSEIGNEMENT SECONDAIRE',
#  'DECLARANT EN DOUANE',
#  'FINANCIER',
#  'EMPLOYE O.A.C.A',
#  'DIRECTEUR GENERAL CHARGE DE MISSION',
#  'MAITRE D APPLICATION',
#  'RESPONSABLE',
#  'DELEGUE',
#  'EMPLOYEE SALIM',
#  'EXPERT DE L ETAT',
#  'MAITRE D EDUCATION PHYSIQUE',
#  'INSPECTEUR  CENTRAL DES FINANCES',
#  'DIRECTRICE',
#  'INGENIEUR ADJOINT',
#  'AGENT STEG',
#  'PROMOTEUR',
#  'ASSISTANTE SOCIALE',
#  'AGENT DE SAISIE',
#  'ASSISTANTE DE DIRECTION',
#  'CONTROLEUR DES TRAVEAUX',
#  'COURTIER',
#  'CONSULTANT',
#  'ECONOMISTE',
#  'SECRETAIRE PRINCIPAL',
#  'EXPERT',
#  'ADMINISTRATEUR ADJOINT',
#  'SOUS CHEF DE SERVICE',
#  'CONSEILLER SOCIAL',
#  'SECRETAIRE GENERAL',
#  'CHIMISTE',
#  'OFFICIER DES DOUANES',
#  'REALISATEUR DE CINEMA ET DE TV',
#  'COLONEL',
#  'PHARMACIEN',
#  'COMMANDANT DE BORD',
#  'INVESTISSEUR',
#  'SPORTIF',
#  'DELEGUE COMMERCIAL',
#  'ACTEUR',
#  'ENTREPRENEUR',
#  'RESPONSABLE EQUIPEMENT',
#  'INFORMATIQUE',
#  'INFOGRAFIST',
#  'AGENT DOUANIER',
#  'SAGE FEMME',
#  'TRANSITAIRE',
#  'SOUS OFFICIER',
#  'SANTE ET ACTION SOCIALE',
#  'AUTRES ARTISANS DE FABRICATION (Y.C. HORLOGERS, MATÉRIEL DE PRÉCISION)',
#  'NETTOYEURS',
#  'FONCTIONNAIRE',
#  'VETERINAIRE',
#  'MANUCURES, ESTHÉTICIENS (SALARIÉS)',
#  'DESSINATEURS EN BÂTIMENT, TRAVAUX PUBLICS',
#  'SOUDEURS QUALIFIÉS SUR MÉTAUX',
#  'VENDEURS POLYVALENTS DES GRANDS MAGASINS',
#  'PETITS ET MOYENS GROSSISTES EN PRODUITS NON ALIMENTAIRES, DE 0 À 9 SALARIÉS',
#  'CADRES DE LA PUBLICITÉ',
#  'GUICHET',
#  'activité sportive',
#  11,
#  'ARTISANS DE L HABILLEMENT, DU TEXTILE ET DU CUIR',
#  'AUCUN',
#  'JURISTES',
#  'EMPLOYE(E)',
#  'AIDES À DOMICILE, AIDES MÉNAGÈRES, TRAVAILLEUSES FAMILIALES',
#  'PLOMBIERS ET CHAUFFAGISTES QUALIFIÉS',
#  'INDUSTRIE METALLURGIQUE',
#  'CHAUFFAGE (COMMERCE D APPAREILS), SANS POSE NI INSTALLATION,SANS DEPÖT DE BOUTEILLE DE GAZ',
#  'BIBLIOTHÉCAIRES, ARCHIVISTES, CONSERVATEURS ET AUTRES CADRES DU PATRIMOINE (FONCTION PUBLIQUE)',
#  'CAPITAINES ET MATELOTS TIMONIERS DE LA NAVIGATION FLUVIALE',
#  'GARDIENNAGE',
#  'CHEFS D ÉQUIPE DU GROS OEUVRE ET DES TRAVAUX PUBLICS',
#  'SOUDEURS MANUELS',
#  'CAPITAINE DE NAVIRE',
#  'LABORATOIRE D ANALYSES MEDICALES, LABORATOIRES DE RECHERCHES, D ESSAIS OU DE CONTRÖLES CHIMIQUE, BIOLOGIQUE, ELECTRIQUE, MECANIQUES',
#  'OPERATEURS SUR CHANTIER',
#  1,
#  'CONSEILS ET EXPERTS LIBÉRAUX EN ÉTUDES ÉCONOMIQUES, ORGANISATION ET RECRUTEMENT, GESTION ET FISCALIT',
#  'POMPIERS (Y.C. POMPIERS MILITAIRES)',
#  'ASSISTANTS DENTAIRES, MÉDICAUX ET VÉTÉRINAIRES, AIDES DE TECHNICIENS MÉDICAUX',
#  'COUVREURS QUALIFIÉS',
#  'AGENTS DE SURVEILLANCE DU PATRIMOINE ET DES ADMINISTRATIONS',
#  'AIDES FAMILIAUX NON SALARIÉS DE PROFESSIONS LIBÉRALES EFFECTUANT UN TRAVAIL ADMINISTRATIF',
#  'OPERATEUR SUR CHANTIER',
#  'INSPECTEURS ET OFFICIERS DE POLICE',
#  'CHEFS DE PETITES SURFACES DE VENTE (SALARIÉS OU MANDATAIRES)',
#  'PROFESSIONS INTERMÉDIAIRES ADMINISTRATIVES DES COLLECTIVITÉS LOCALES',
#  'ANIMATEURS SOCIOCULTURELS ET DE LOISIRS',
#  'SERVEURS, COMMIS DE RESTAURANT, GARÇONS (BAR, BRASSERIE, CAFÉ OU RESTAURANT)',
#  'BOIS (TRAVAIL) MENUISERIES',
#  'ARTISANS BOUCHERS, DE 0 À 9 SALARIÉS',
#  'MÉCANICIENS QUALIFIÉS DE MAINTENANCE, ENTRETIEN : ÉQUIPEMENTS INDUSTRIELS',
#  'INGÉNIEURS ET CADRES TECHNICO-COMMERCIAUX EN INFORMATIQUE ET TÉLÉCOMMUNICATIONS',
#  'GENDARMES (DE GRADE INFÉRIEUR À ADJUDANT)',
#  'ESTHETICIENNE',
#  'PHARMACIENS LIBÉRAUX',
#  'PETITS ET MOYENS DÉTAILLANTS EN ALIMENTATION SPÉCIALISÉE, DE 0 À 9 SALARIÉS',
#  'AIDE SOIGNANTE',
#  'CHEFS DE CHANTIER (NON CADRES)',
#  'ARTISANS CHARCUTIERS, DE 0 À 9 SALARIÉS',
#  'STAGIAIRE A TUNISAIR HANDLING',
#  'MAÎTRES D ÉQUIPAGE DE LA MARINE MARCHANDE ET DE LA PÊCHE',
#  'CHEFS D ÉTABLISSEMENT DE L ENSEIGNEMENT SECONDAIRE ET INSPECTEURS',
#  'INGÉNIEURS ET CADRES D ÉTUDE DU BÂTIMENT ET DES TRAVAUX PUBLICS',
#  'PETITS ET MOYENS DÉTAILLANTS EN ALIMENTATION GÉNÉRALE, DE 0 À 9 SALARIÉS',
#  'JOURNALISTES (Y. C. RÉDACTEURS EN CHEF)',
#  'OUVRIERS QUALIFIÉS DU TRAVAIL INDUSTRIEL DU CUIR',
#  'MASSEURS-KINÉSITHÉRAPEUTES RÉÉDUCATEURS, SALARIÉS',
#  'PRÉPARATEURS EN PHARMACIE',
#  'CONTREMAÎTRES ET AGENTS D ENCADREMENT (NON CADRES) EN AGRICULTURE, SYLVICULTURE',
#  'INGÉNIEURS ET CADRES D ÉTUDE, RECHERCHE ET DÉVELOPPEMENT EN INFORMATIQUE',
#  'PARFUMERIE',
#  'INGÉNIEURS ET CADRES D ÉTUDE ET D EXPLOITATION DE L AGRICULTURE, LA PÊCHE, LES EAUX ET FORÊTS',
#  'INGÉNIEURS ET CADRES TECHNIQUES DE L EXPLOITATION DES TRANSPORTS',
#  'PETITS ET MOYENS GROSSISTES EN ALIMENTATION, DE 0 À 9 SALARIÉS',
#  'AUTRES ARTISANS DE L ALIMENTATION, DE 0 À 9 SALARIÉS',
#  'STAGIAIRE',
#  'CONDUCTEURS DE TRAVAUX (NON CADRES)',
#  'MONITEURS D ÉCOLE DE CONDUITE',
#  'PHARMACIENS SALARIÉS',
#  'AGENT COMMERCIAL ',
#  'ARTISANS PLOMBIERS, CHAUFFAGISTES',
#  'ARTISANS SERRURIERS, MÉTALLIERS',
#  'ELEVE',
#  'DÉTAILLANTS EN DROGUERIE, BAZAR, QUINCAILLERIE, BRICOLAGE, DE 0 À 9 SALARIÉS',
#  'MAÎTRISE ET TECHNICIENS DES SERVICES FINANCIERS OU COMPTABLES',
#  'CONDUCTEURS D ENGIN LOURD DE MANOEUVRE',
#  'OUVRIERS QUALIFIÉS DES TRAVAUX PUBLICS (SALARIÉS DE L ETAT ET DES COLLECTIVITÉS LOCALES)',
#  'AUTRES MONTEURS CÂBLEURS EN ÉLECTRONIQUE',
#  'COIFFEURS SALARIÉS',
#  'OPÉRATEURS QUALIFIÉS SUR MACHINES AUTOMATIQUES EN PRODUCTION ÉLECTRIQUE OU ÉLECTRONIQUE',
#  'MECANICIEN DE NAVIRE',
#  'GARAGE,PARKING AUTOMOBILE',
#  'MEUBLES LITERIE(COMMERCE DE, SANS INSTALLATION, AVEC INSTALLATION)',
#  'CONDUCTEURS D ENGIN LOURD DE LEVAGE',
#  'VITICULTEURS, ARBORICULTEURS FRUITIERS, SUR GRANDE EXPLOITATION',
#  'CADRES SPÉCIALISTES DES RESSOURCES HUMAINES ET DU RECRUTEMENT',
#  'CHERCHEURS DE LA RECHERCHE PUBLIQUE',
#  'NOTAIRES',
#  'BOULANGERS, PÂTISSIERS (SAUF ACTIVITÉ INDUSTRIELLE)',
#  'JARDINIERS',
#  'AIDES FAMILIAUX NON SALARIÉS OU ASSOCIÉS D ARTISANS, EFFECTUANT UN TRAVAIL ADMINISTRATIF OU COMMERCI',
#  'CHEFS DE PRODUITS, ACHETEURS DU COMMERCE ET AUTRES CADRES DE LA MERCATIQUE',
#  'CONSEILLERS PRINCIPAUX D ÉDUCATION',
#  'ACTEUR DE THEATRE, ARTISTES DUR SCENE',
#  'VENDEUR DU BOIS',
#  'HÔTESSES DE L AIR ET STEWARDS',
#  'ASSISTANTES MATERNELLES, GARDIENNES D ENFANTS, FAMILLES D ACCUEIL',
#  'TECHNICIENS DES OPÉRATIONS BANCAIRES',
#  'PERSONNELS ADMINISTRATIFS DE CATÉGORIE B DES COLLECTIVITÉS LOCALES ET DES HÔPITAUX (HORS ENSEIGNEMEN',
#  'CHEFS D ÉTABLISSEMENTS ET RESPONSABLES DE L EXPLOITATION BANCAIRE',
#  'CÂBLEURS QUALIFIÉS, BOBINIERS QUALIFIÉS',
#  'DÉTAILLANTS EN PRODUITS DE BEAUTÉ, DE LUXE (HORS BIENS CULTURELS), DE 0 À 9 SALARIÉS',
#  'OFFICIER DES DOUANES TUNISIENNES',
#  'ARTISANS BOULANGERS, PÂTISSIERS, DE 0 À 9 SALARIÉS',
#  'PHARMACIE (SANS LABORATOIRE D ANALYSE MEDICALES)',
#  'CADRES INFIRMIERS ET ASSIMILÉS',
#  'MONTEURS CÂBLEURS QUALIFIÉS EN ÉLECTRICITÉ',
#  'MANUTENTIONNAIRES NON QUALIFIÉS',
#  'CONDUCTEURS QUALIFIÉS D ENGINS DE CHANTIERS DU BÂTIMENT ET DES TRAVAUX PUBLICS',
#  'DÉTAILLANTS EN AMEUBLEMENT, DÉCOR, ÉQUIPEMENT DU FOYER, DE 0 À 9 SALARIÉS',
#  'RÉGLEURS QUALIFIÉS D ÉQUIPEMENTS DE FABRICATION (HORS TRAVAIL DES MÉTAUX ET MÉCANIQUE)',
#  'CHEFS DE MOYENNE ENTREPRISE, DE 50 À 499 SALARIÉS',
#  'PSYCHOLOGUES, PSYCHANALYSTES, PSYCHOTHÉRAPEUTES (NON MÉDECINS)',
#  'AIDES-SOIGNANTS (DE LA FONCTION PUBLIQUE OU DU SECTEUR PRIVÉ)',
#  'ELECTRICIENS, ÉLECTRONICIENS QUALIFIÉS EN MAINTENANCE, ENTRETIEN : ÉQUIPEMENTS NON INDUSTRIELS',
#  'PROFESSEURS AGRÉGÉS ET CERTIFIÉS EN FONCTION DANS L ENSEIGNEMENT SUPÉRIEUR',
#  'IMPRIMERIES',
#  'MINISTRE',
#  'CONVOYEURS DE FONDS, GARDES DU CORPS, ENQUÊTEURS PRIVÉS ET MÉTIERS ASSIMILÉS (SALARIÉS)',
#  'MAÎTRISE DE RESTAURATION  : CUISINE/PRODUCTION',
#  'ARTISANS RÉPARATEURS DIVERS',
#  'PREMIER CONSEILLER PRINCIPAL',
#  'INGÉNIEURS ET CADRES DE LA PRODUCTION ET DE LA DISTRIBUTION D ÉNERGIE, EAU',
#  'ALIMENTATION GENERALE MAGASINS A RAYONS MULTIPLES, SUPERETTES, SUPERMARCHES',
#  12,
#  'DÉPANNEURS QUALIFIÉS EN RADIOTÉLÉVISION, ÉLECTROMÉNAGER, MATÉRIEL ÉLECTRONIQUE (SALARIÉS)',
#  'PERSONNELS DE DIRECTION DE LA FONCTION PUBLIQUE (ETAT, COLLECTIVITÉS LOCALES, HÔPITAUX)',
#  'CONDUCTEURS LIVREURS, COURSIERS (SALARIÉS)',
#  'OPÉRATEURS QUALIFIÉS D USINAGE DES MÉTAUX SUR AUTRES MACHINES (SAUF MOULISTES)',
#  'MÉCANICIENS QUALIFIÉS EN MAINTENANCE, ENTRETIEN, RÉPARATION : AUTOMOBILE',
#  'PLATEFORMISTES, CONTRÔLEURS QUALIFIÉS DE MATÉRIEL ÉLECTRIQUE OU ÉLECTRONIQUE',
#  'AIDES MÉDICO-PSYCHOLOGIQUES',
#  'ANCIENS AGRICULTEURS EXPLOITANTS',
#  'OFFICIER DE POLICE SANITAIRE',
#  'JARDIN D ENFANT',
#  'AMBULANCIERS SALARIÉS (DU SECTEUR PUBLIC OU DU SECTEUR PRIVÉ)',
#  'EMPLOYÉS DE FRANCE TÉLÉCOM (STATUT PUBLIC)',
#  'FINANCIERE',
#  'EMPLOYÉS DE L HÔTELLERIE : RÉCEPTION ET HALL',
#  'CHAUDRONNIERS-TÔLIERS INDUSTRIELS, OPÉRATEURS QUALIFIÉS DU TRAVAIL EN FORGE, CONDUCTEURS QUALIFIÉS D',
#  'POMPISTES ET GÉRANTS DE STATION-SERVICE (SALARIÉS OU MANDATAIRES)',
#  'AGENTS ET HÔTESSES D ACCUEIL ET D INFORMATION (HORS HÔTELLERIE)',
#  'OUVRIERS QUALIFIÉS DE L ASSAINISSEMENT ET DU TRAITEMENT DES DÉCHETS',
#  'OUVRIERS NON QUALIFIÉS DES TRAVAUX PUBLICS DE L ETAT ET DES COLLECTIVITÉS LOCALES',
#  'OPÉRATEURS DE LA TRANSFORMATION DES VIANDES',
#  'AGENTS TECHNIQUES FORESTIERS, GARDES DES ESPACES NATURELS',
#  'OUVRIERS QUALIFIÉS DE CONTRÔLE ET D ESSAIS EN MÉCANIQUE',
#  'AUTRES OPÉRATEURS TRAVAILLANT SUR INSTALLATIONS OU MACHINES : INDUSTRIE AGROALIMENTAIRE (HORS TRANSF',
#  'AUTRES SPÉCIALISTES DE LA RÉÉDUCATION, LIBÉRAUX',
#  'CÂBLEURS QUALIFIÉS EN ÉLECTRONIQUE (PROTOTYPE, UNITÉ, PETITE SÉRIE)',
#  'PERSONNES EXERÇANT UN MANDAT POLITIQUE OU SYNDICAL',
#  'HOMMES DU RANG (SAUF POMPIERS MILITAIRES)',
#  'OUVRIERS DE LA VITICULTURE OU DE L ARBORICULTURE FRUITIÈRE',
#  'FLEURISTES, DE 0 À 9 SALARIÉS',
#  'DIRECTEURS DE CENTRES SOCIOCULTURELS ET DE LOISIRS',
#  'SERVEURS, COMMIS DE RESTAURANT, GARÇONS NON QUALIFIÉS',
#  'ELEVEURS DE GRANIVORES ET ÉLEVEURS MIXTES, SUR PETITE EXPLOITATION',
#  'ENZYME ACIDE ASCORBIQUE',
#  'ARTISANS MENUISIERS DU BÂTIMENT, CHARPENTIERS EN BOIS',
#  'ELEVEURS D HERBIVORES, SUR PETITE EXPLOITATION',
#  'EXPLOITANTS DE CAFÉ, RESTAURANT, HÔTEL, DE 3 À 9 SALARIÉS',
#  'ARTISANS ÉLECTRICIENS DU BÂTIMENT',
#  7,
#  'EXPLOITANTS DE PETIT CAFÉ, DÉBIT DE BOISSON, ASSOCIÉ OU NON À UNE AUTRE ACTIVITÉ HORS RESTAURATION,',
#  'ARTISANS MÉCANICIENS EN MACHINES AGRICOLES',
#  'ARTISANS MÉCANICIENS RÉPARATEURS D AUTOMOBILES',
#  'VITICULTEURS, ARBORICULTEURS FRUITIERS, SUR PETITE EXPLOITATION',
#  'DÉTAILLANTS EN BIENS CULTURELS (LIVRES, DISQUES, MULTIMÉDIA, OBJETS D ART), DE 0 À 9 SALARIÉS',
#  'ARTISANS EN MÉCANIQUE GÉNÉRALE, FABRICATION ET TRAVAIL DES MÉTAUX (HORS HORLOGERIE ET MATÉRIEL DE PR',
#  'DACTYLOS, STÉNODACTYLOS (SANS SECRÉTARIAT), OPÉRATEURS DE TRAITEMENT DE TEXTE',
#  'MONTEURS QUALIFIÉS D ENSEMBLES MÉCANIQUES',
#  'marin ',
#  'ELECTROMÉCANICIENS, ÉLECTRICIENS QUALIFIÉS D ENTRETIEN : ÉQUIPEMENTS INDUSTRIELS',
#  'COMMERCE DE SACHERIE , SACS EN BULL D AIR ET ROULEAUX',
#  'ARTISANS DU PAPIER, DE L IMPRIMERIE ET DE LA REPRODUCTION',
#  'OUVRIERS QUALIFIÉS DE LA COUPE DES VÊTEMENTS ET DE L HABILLEMENT, AUTRES OPÉRATEURS DE CONFECTION QU',
#  'ARTISANS DE FABRICATION EN MATÉRIAUX DE CONSTRUCTION (HORS ARTISANAT D ART)']

# %%
df2 = df.copy()

# %%
# First, handle missing/unknown values
df['LIB_PROFESSION'] = df['LIB_PROFESSION'].fillna('NON_RENSEIGNE')
mask = df['LIB_PROFESSION'].str.strip() == ''
df.loc[mask, 'LIB_PROFESSION'] = 'NON_RENSEIGNE'

# Define comprehensive profession grouping function
def group_profession(profession):
    if pd.isna(profession):
        return 'NON_RENSEIGNE'
    
    prof_str = str(profession).upper()
    
    # Handle non-specific categories first
    if any(word in prof_str for word in ['NON FOURNI', 'NON DEFINIE', 'NON_RENSEIGNE', 'NON RENSEIGNE']):
        return 'NON_RENSEIGNE'
    if 'RETRAITE' in prof_str or 'ANCIEN' in prof_str:
        return 'RETRAITES'
    if any(word in prof_str for word in ['ETUDIANT', 'ELEVE', 'ECOLIER', 'STAGIAIRE']):
        return 'ETUDIANTS'
    if any(word in prof_str for word in ['CHOMAGE', 'SANS EMPLOI', 'AUCUN', 'AUCUNE ACTIVITE']):
        return 'SANS_EMPLOI'
    
    # High-income professionals (low risk, high asset value)
    if any(word in prof_str for word in ['CADRE', 'INGENIEUR', 'ARCHITECTE', 'EXPERT', 'CONSULTANT', 
                                       'DIRECTEUR', 'MANAGER', 'CHEF SERVICE', 'RESPONSABLE', 'BANQUIER',
                                       'AVOCAT', 'MEDECIN', 'PHARMACIEN', 'DENTISTE', 'VETERINAIRE',
                                       'JOURNALISTE', 'PROFESSEUR', 'ENSEIGNANT', 'CHERCHEUR', 'MAITRE']):
        return 'CADRES_SUPERIEURS'
    
    # Commercial and sales professions
    if any(word in prof_str for word in ['COMMERCIAL', 'VENDEUR', 'GERANT', 'NEGOCIANT', 'REPRESENTANT',
                                       'DELEGUE', 'COURTIER', 'AGENT COMMERCIAL', 'CONSEILLER COMMERCIAL']):
        return 'COMMERCE_ET_VENTE'
    
    # Technical and engineering professions
    if any(word in prof_str for word in ['TECHNICIEN', 'ELECTRICIEN', 'MECANICIEN', 'PLOMBIER', 'CHAUFFAGISTE',
                                       'SOUDEUR', 'MONTEUR', 'OPERATEUR', 'CONTRÔLEUR', 'MAINTENANCE']):
        return 'TECHNICIENS_ET_ARTISANS'
    
    # Administrative and office workers
    if any(word in prof_str for word in ['ADMINISTRATIF', 'SECRETAIRE', 'COMPTABLE', 'GESTIONNAIRE', 'AGENT',
                                       'EMPLOYE', 'ASSISTANT', 'CAISSIER', 'STANDARDISTE', 'DACTYLO']):
        return 'ADMINISTRATION_ET_BUREAU'
    
    # Healthcare professions
    if any(word in prof_str for word in ['INFIRMIER', 'AIDE SOIGNANT', 'KINESITHERAPEUTE', 'SAGE FEMME',
                                       'MEDICAL', 'PHARMACEUTIQUE', 'BIOLOGISTE', 'RADIOLOGUE']):
        return 'SANTE_ET_MEDICAL'
    
    # Security and defense
    if any(word in prof_str for word in ['POLICE', 'GENDARME', 'MILITAIRE', 'SECURITE', 'SURVEILLANT',
                                       'GARDIEN', 'DOUANE', 'POMPIER', 'AGENT DE SECURITE']):
        return 'SECURITE_ET_DEFENSE'
    
    # Transportation professionals (higher risk)
    if any(word in prof_str for word in ['CHAUFFEUR', 'CONDUCTEUR', 'PILOTE', 'TAXISTE', 'ROUTIER',
                                       'TRANSPORT', 'LIVREUR', 'AMBULANCIER', 'MARIN']):
        return 'TRANSPORTS'
    
    # Education and social services
    if any(word in prof_str for word in ['EDUCATEUR', 'FORMATEUR', 'ANIMATEUR', 'ASSISTANT SOCIAL', 
                                       'MONITEUR', 'PROFESSEUR', 'ENSEIGNANT', 'INSTITUTEUR']):
        return 'EDUCATION_ET_SOCIAL'
    
    # Construction and manual labor (higher physical risk)
    if any(word in prof_str for word in ['OUVRIER', 'MACON', 'MENUISIER', 'PEINTRE', 'CARRELEUR',
                                       'PLATRIER', 'CHARBENTIER', 'CONSTRUCT', 'BATIMENT', 'CHANTIER']):
        return 'BATIMENT_ET_TRAVAUX'
    
    # Agriculture and fishing
    if any(word in prof_str for word in ['AGRICULTEUR', 'ELEVEUR', 'PECHEUR', 'VITICULTEUR', 'ARBORICULTEUR',
                                       'JARDINIER', 'FORESTIER', 'HORTICULTEUR']):
        return 'AGRICULTURE_ET_PECHE'
    
    # Hospitality and services
    if any(word in prof_str for word in ['HOTESSE', 'SERVEUR', 'CUISINIER', 'RESTAURATION', 'HOTELLERIE',
                                       'COIFFEUR', 'ESTHETICIEN', 'MANUCURE', 'TOURISME']):
        return 'HOTELLERIE_RESTAURATION'
    
    # Arts and entertainment
    if any(word in prof_str for word in ['ARTISTE', 'ACTEUR', 'MUSICIEN', 'PHOTOGRAPHE', 'DESSINATEUR',
                                       'REALISATEUR', 'DECORATEUR', 'STYLISTE']):
        return 'ARTS_ET_SPECTACLE'
    
    # Industrial workers
    if any(word in prof_str for word in ['INDUSTRIE', 'USINE', 'PRODUCTION', 'MANUTENTION', 'MACHINISTE',
                                       'FABRICATION', 'ASSEMBLAGE']):
        return 'INDUSTRIE_ET_PRODUCTION'
    
    return 'AUTRES_PROFESSIONS'

# Apply the grouping
df['PROFESSION_GROUP'] = df['LIB_PROFESSION'].apply(group_profession)

# Verify the results
print("Profession groups distribution:")
print(df['PROFESSION_GROUP'].value_counts())
print(f"\nNumber of unique profession groups: {df['PROFESSION_GROUP'].nunique()}")

# Show sample mapping for verification
sample_professions = ['INGENIEUR', 'COMMERCIAL', 'OUVRIER', 'INFIRMIER', 'CHAUFFEUR', 'PROFESSEUR']
for prof in sample_professions:
    print(f"{prof} -> {group_profession(prof)}")
# Out:
# Profession groups distribution:
# PROFESSION_GROUP
# NON_RENSEIGNE               9922
# COMMERCE_ET_VENTE           7838
# ADMINISTRATION_ET_BUREAU    4473
# AUTRES_PROFESSIONS          4185
# AGRICULTURE_ET_PECHE        3468
# CADRES_SUPERIEURS           3121
# RETRAITES                   3041
# SECURITE_ET_DEFENSE         1408
# BATIMENT_ET_TRAVAUX         1363
# ETUDIANTS                    771
# TECHNICIENS_ET_ARTISANS      734
# ARTS_ET_SPECTACLE            630
# TRANSPORTS                   552
# SANTE_ET_MEDICAL             301
# EDUCATION_ET_SOCIAL          120
# INDUSTRIE_ET_PRODUCTION       71
# HOTELLERIE_RESTAURATION       65
# SANS_EMPLOI                    2
# Name: count, dtype: int64
#
# Number of unique profession groups: 18
# INGENIEUR -> CADRES_SUPERIEURS
# COMMERCIAL -> COMMERCE_ET_VENTE
# OUVRIER -> BATIMENT_ET_TRAVAUX
# INFIRMIER -> SANTE_ET_MEDICAL
# CHAUFFEUR -> TRANSPORTS
# PROFESSEUR -> CADRES_SUPERIEURS

# %%
def assess_data_quality(df):
    """Comprehensive data quality assessment"""
    
    # Missing values analysis
    missing_stats = pd.DataFrame({
        'Missing_Count': df.isnull().sum(),
        'Missing_Percentage': (df.isnull().sum() / len(df)) * 100,
        'Unique_Values': df.nunique()
    })
    
    print("Missing Values Analysis:")
    print(missing_stats)
    
    # Data type validation
    print("\nData Type Validation:")
    for col in df.columns:
        print(f"{col}: {df[col].dtype}")
    
    return missing_stats


quality_report = assess_data_quality(df2)
# Out:
# Missing Values Analysis:
#                         Missing_Count  Missing_Percentage  Unique_Values
# REF_PERSONNE                        0            0.000000          42065
# NOM_PRENOM                          0            0.000000          42065
# DATE_NAISSANCE                      0            0.000000          18100
# LIEU_NAISSANCE                      0            0.000000           5451
# CODE_SEXE                           0            0.000000              3
# SITUATION_FAMILIALE                 0            0.000000              5
# NUM_PIECE_IDENTITE                  0            0.000000          42065
# LIB_SECTEUR_ACTIVITE                0            0.000000             31
# LIB_PROFESSION                   2801            6.658742            680
# VILLE                           14347           34.106740           3308
# LIB_GOUVERNORAT                 26769           63.637228             24
# VILLE_GOUVERNORAT                   0            0.000000           3979
# AGE                                 0            0.000000             82
# id_length                           0            0.000000              1
# SECTEUR_ACTIVITE_GROUP              0            0.000000             13
#
# Data Type Validation:
# REF_PERSONNE: int64
# NOM_PRENOM: object
# DATE_NAISSANCE: datetime64[ns]
# LIEU_NAISSANCE: object
# CODE_SEXE: object
# SITUATION_FAMILIALE: object
# NUM_PIECE_IDENTITE: int64
# LIB_SECTEUR_ACTIVITE: object
# LIB_PROFESSION: object
# VILLE: object
# LIB_GOUVERNORAT: object
# VILLE_GOUVERNORAT: object
# AGE: float64
# id_length: int64
# SECTEUR_ACTIVITE_GROUP: object

# %% [markdown]
# Geographic Columns

# %%
# Analyze location data
geo_cols = ['VILLE', 'LIB_GOUVERNORAT', 'VILLE_GOUVERNORAT']

for col in geo_cols:
    print(f"\n{col} Analysis:")
    print("Missing values:", df[col].isnull().sum())
    print("Unique values:", df[col].nunique())
    
    if df[col].nunique() < 20:  # Show all if few unique values
        print("Value counts:\n", df[col].value_counts())
    else:
        print("Top 10 values:\n", df[col].value_counts().head(10))
# Out:
# VILLE Analysis:
# Missing values: 14347
# Unique values: 3308
# Top 10 values:
#  VILLE
# GABES          1704
# SFAX           1220
# TUNIS          1179
# BIZERTE         887
# SOUSSE          673
# ARIANA          646
# MONASTIR        549
# BEJA            540
# BEN AROUS       514
# SIDI BOUZID     498
# Name: count, dtype: int64
#
# LIB_GOUVERNORAT Analysis:
# Missing values: 26769
# Unique values: 24
# Top 10 values:
#  LIB_GOUVERNORAT
# TUNIS          1911
# BEN AROUS      1162
# BIZERTE        1035
# GABES          1035
# SFAX           1011
# SILIANA         919
# ARIANA          912
# SOUSSE          746
# NABEUL          734
# SIDI BOUZID     727
# Name: count, dtype: int64
#
# VILLE_GOUVERNORAT Analysis:
# Missing values: 0
# Unique values: 3979
# Top 10 values:
#  VILLE_GOUVERNORAT
#  -                           14300
# GABES -                       1646
# SFAX - SFAX                    720
# TUNIS - TUNIS                  653
# BIZERTE - BIZERTE              635
# TUNIS -                        508
# SFAX -                         500
#   -                            467
# SIDI BOUZID - SIDI BOUZID      431
# SILIANA - SILIANA              409
# Name: count, dtype: int64

# %%
# Clean geographic columns
geo_cols = ["VILLE", 'LIB_GOUVERNORAT', 'VILLE_GOUVERNORAT']

for col in geo_cols:
    print(f"\n--- Cleaning {col} ---")
    
    # Check initial state
    print(f"Initial missing values: {df[col].isnull().sum()}")
    whitespace_count = (df[col].str.strip() == '').sum()
    print(f"Initial whitespace-only values: {whitespace_count}")
    
    # Replace whitespace-only strings with NaN first (to handle them together)
    mask_whitespace = df[col].str.strip() == ''
    df.loc[mask_whitespace, col] = np.nan
    
    # Now fill all missing values (both original NaN and converted whitespace) with 'UNKNOWN'
    df[col] = df[col].fillna('UNKNOWN')
    
    # Verify cleaning
    print(f"Final missing values: {df[col].isnull().sum()}")
    print(f"Final whitespace-only values: {(df[col].str.strip() == '').sum()}")
    
    # Show updated value counts
    if df[col].nunique() < 20:
        print(f"Value counts after cleaning:\n{df[col].value_counts()}")
    else:
        print(f"Top 10 values after cleaning:\n{df[col].value_counts().head(10)}")

# Final verification
print("\n=== FINAL SUMMARY ===")
for col in geo_cols:
    missing_final = df[col].isnull().sum()
    unknown_count = (df[col] == 'UNKNOWN').sum()
    print(f"{col}: {missing_final} missing, {unknown_count} marked as 'UNKNOWN'")
# Out:
# --- Cleaning VILLE ---
# Initial missing values: 14347
# Initial whitespace-only values: 468
# Final missing values: 0
# Final whitespace-only values: 0
# Top 10 values after cleaning:
# VILLE
# UNKNOWN      14815
# GABES         1704
# SFAX          1220
# TUNIS         1179
# BIZERTE        887
# SOUSSE         673
# ARIANA         646
# MONASTIR       549
# BEJA           540
# BEN AROUS      514
# Name: count, dtype: int64
#
# --- Cleaning LIB_GOUVERNORAT ---
# Initial missing values: 26769
# Initial whitespace-only values: 0
# Final missing values: 0
# Final whitespace-only values: 0
# Top 10 values after cleaning:
# LIB_GOUVERNORAT
# UNKNOWN      26769
# TUNIS         1911
# BEN AROUS     1162
# BIZERTE       1035
# GABES         1035
# SFAX          1011
# SILIANA        919
# ARIANA         912
# SOUSSE         746
# NABEUL         734
# Name: count, dtype: int64
#
# --- Cleaning VILLE_GOUVERNORAT ---
# Initial missing values: 0
# Initial whitespace-only values: 0
# Final missing values: 0
# Final whitespace-only values: 0
# Top 10 values after cleaning:
# VILLE_GOUVERNORAT
#  -                           14300
# GABES -                       1646
# SFAX - SFAX                    720
# TUNIS - TUNIS                  653
# BIZERTE - BIZERTE              635
# TUNIS -                        508
# SFAX -                         500
#   -                            467
# SIDI BOUZID - SIDI BOUZID      431
# SILIANA - SILIANA              409
# Name: count, dtype: int64
#
# === FINAL SUMMARY ===
# VILLE: 0 missing, 14815 marked as 'UNKNOWN'
# LIB_GOUVERNORAT: 0 missing, 26769 marked as 'UNKNOWN'
# VILLE_GOUVERNORAT: 0 missing, 0 marked as 'UNKNOWN'

# %%
quality_report = assess_data_quality(df)
# Out:
# Missing Values Analysis:
#                         Missing_Count  Missing_Percentage  Unique_Values
# REF_PERSONNE                        0                 0.0          42065
# NOM_PRENOM                          0                 0.0          42065
# DATE_NAISSANCE                      0                 0.0          18100
# LIEU_NAISSANCE                      0                 0.0           5451
# CODE_SEXE                           0                 0.0              3
# SITUATION_FAMILIALE                 0                 0.0              5
# NUM_PIECE_IDENTITE                  0                 0.0          42065
# LIB_SECTEUR_ACTIVITE                0                 0.0             31
# LIB_PROFESSION                      0                 0.0            681
# VILLE                               0                 0.0           3308
# LIB_GOUVERNORAT                     0                 0.0             25
# VILLE_GOUVERNORAT                   0                 0.0           3979
# AGE                                 0                 0.0             82
# id_length                           0                 0.0              1
# SECTEUR_ACTIVITE_GROUP              0                 0.0             13
# PROFESSION_GROUP                    0                 0.0             18
#
# Data Type Validation:
# REF_PERSONNE: int64
# NOM_PRENOM: object
# DATE_NAISSANCE: datetime64[ns]
# LIEU_NAISSANCE: object
# CODE_SEXE: object
# SITUATION_FAMILIALE: object
# NUM_PIECE_IDENTITE: int64
# LIB_SECTEUR_ACTIVITE: object
# LIB_PROFESSION: object
# VILLE: object
# LIB_GOUVERNORAT: object
# VILLE_GOUVERNORAT: object
# AGE: float64
# id_length: int64
# SECTEUR_ACTIVITE_GROUP: object
# PROFESSION_GROUP: object

# %%
df.columns
# Out:
# Index(['REF_PERSONNE', 'NOM_PRENOM', 'DATE_NAISSANCE', 'LIEU_NAISSANCE',
#        'CODE_SEXE', 'SITUATION_FAMILIALE', 'NUM_PIECE_IDENTITE',
#        'LIB_SECTEUR_ACTIVITE', 'LIB_PROFESSION', 'VILLE', 'LIB_GOUVERNORAT',
#        'VILLE_GOUVERNORAT', 'AGE', 'id_length', 'SECTEUR_ACTIVITE_GROUP',
#        'PROFESSION_GROUP'],
#       dtype='object')

# %% [markdown]
# Exporting the data

# %%
import pickle

# %%
path = '../../data'
df.to_pickle('../../data/clients_phy.pkl')
